# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# base url of the best sellers page for teaching & education books
base_url = "import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import numpy as np
from urllib.parse import urljoin
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import joblib
import os

def scrape_books_toscrape(base_url='http://books.toscrape.com/', num_pages=5):
    all_books = []
    for page in range(1, num_pages + 1):
        url = base_url if page == 1 else urljoin(base_url, f'catalogue/page-{page}.html')
        print(f"Scraping page {page}/{num_pages}: {url}")

        try:
            time.sleep(random.uniform(1, 3))
            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            book_containers = soup.select('article.product_pod')

            for book in book_containers:
                title = book.h3.a['title']
                price_text = book.select_one('div.product_price p.price_color').text
                price = re.sub(r'[^0-9.]', '', price_text)
                price = pd.to_numeric(price, errors='coerce')
                rating_class = book.select_one('p.star-rating')['class'][1]
                rating_map = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}
                rating = rating_map.get(rating_class, 0)

                availability_text = book.select_one('p.availability').text.strip()
                in_stock = 1 if 'In stock' in availability_text else 0
                detail_url = urljoin(base_url, book.h3.a['href'])
                category, description = "Unknown", "No description available"

                try:
                    time.sleep(random.uniform(0.5, 1.5))
                    detail_response = requests.get(detail_url, headers=headers)
                    detail_response.raise_for_status()
                    detail_soup = BeautifulSoup(detail_response.text, 'html.parser')
                    breadcrumb = detail_soup.select('ul.breadcrumb li')
                    if len(breadcrumb) >= 3:
                        category = breadcrumb[2].text.strip()
                    desc_element = detail_soup.select_one('div#product_description + p')
                    if desc_element:
                        description = desc_element.text.strip()
                except Exception as e:
                    print(f"Error fetching detail page for {title}: {e}")

                book_data = {'title': title, 'price': price, 'rating': rating, 'category': category,
                             'in_stock': in_stock, 'description': description, 'url': detail_url}
                all_books.append(book_data)
        except Exception as e:
            print(f"Error scraping page {page}: {e}")

    return pd.DataFrame(all_books)

def clean_book_data(df):
    df_clean = df.copy()
    df_clean['description'].fillna('No description available', inplace=True)
    df_clean['title_length'] = df_clean['title'].str.len()
    df_clean['desc_length'] = df_clean['description'].str.len()
    category_dummies = pd.get_dummies(df_clean['category'], prefix='category')
    return pd.concat([df_clean, category_dummies], axis=1)

def build_book_price_model(df):
    feature_cols = ['rating', 'in_stock', 'title_length', 'desc_length'] + [col for col in df.columns if col.startswith('category_')]
    y = df['price']
    X_numerical = df[feature_cols]
    X_num_train, X_num_test, y_train, y_test = train_test_split(X_numerical, y, test_size=0.2, random_state=42)

    title_vectorizer = TfidfVectorizer(max_features=100, stop_words='english')
    desc_vectorizer = TfidfVectorizer(max_features=200, stop_words='english')

    X_title_train = title_vectorizer.fit_transform(df.loc[X_num_train.index, 'title'])
    X_title_test = title_vectorizer.transform(df.loc[X_num_test.index, 'title'])
    X_desc_train = desc_vectorizer.fit_transform(df.loc[X_num_train.index, 'description'])
    X_desc_test = desc_vectorizer.transform(df.loc[X_num_test.index, 'description'])

    scaler = StandardScaler()
    X_num_train_scaled = scaler.fit_transform(X_num_train)
    X_num_test_scaled = scaler.transform(X_num_test)

    X_train_combined = np.hstack((X_num_train_scaled, X_title_train.toarray(), X_desc_train.toarray()))
    X_test_combined = np.hstack((X_num_test_scaled, X_title_test.toarray(), X_desc_test.toarray()))

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train_combined, y_train)
    y_pred = model.predict(X_test_combined)

    return {'model': model, 'feature_cols': feature_cols, 'title_vectorizer': title_vectorizer,
            'desc_vectorizer': desc_vectorizer, 'scaler': scaler,
            'metrics': {'mse': mean_squared_error(y_test, y_pred),
                        'rmse': np.sqrt(mean_squared_error(y_test, y_pred)),
                        'r2': r2_score(y_test, y_pred)}}

def save_model_components(model_data, output_dir='book_model'):
    os.makedirs(output_dir, exist_ok=True)
    joblib.dump(model_data['model'], f"{output_dir}/model.joblib")
    joblib.dump(model_data['title_vectorizer'], f"{output_dir}/title_vectorizer.joblib")
    joblib.dump(model_data['desc_vectorizer'], f"{output_dir}/desc_vectorizer.joblib")
    joblib.dump(model_data['scaler'], f"{output_dir}/scaler.joblib")
    pd.Series(model_data['feature_cols']).to_csv(f"{output_dir}/feature_cols.csv", index=False)

def main():
    books_df = scrape_books_toscrape(num_pages=10)
    books_df.to_csv("scraped_books_raw.csv", index=False)
    books_df_clean = clean_book_data(books_df)
    books_df_clean.to_csv("scraped_books_clean.csv", index=False)
    model_data = build_book_price_model(books_df_clean)
    save_model_components(model_data)
    print("Model training complete and components saved.")

if __name__ == "__main__":
    main()
}"



# http headers to mimic a browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# %%
# initialize a list to store book data
book_list = []

# iterate over the first 3 pages to get top 50 books (assuming each page has about 20 items)
for page in range(1, 4):
    # construct the URL for the current page
    url = base_url.format(page, page)

    # send a GET request to the url
    response = requests.get(url, headers=headers)

    # parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, "lxml")

    # find all the book elements
    books = soup.find_all("div", {"class": "zg-grid-general-faceout"})

    # iterate over each book element to extract data
    for book in books:
        if len(book_list) < 50:  # stop once we've collected 50 books
            author = book.find("a", class_="a-size-small a-link-child").get_text(strip=True) if book.find("a", class_="a-size-small a-link-child") else "N/A"
            rating = book.find("span", class_="a-icon-alt").get_text(strip=True) if book.find("span", class_="a-icon-alt") else "N/A"

            # append the extracted data to the book_list
            book_list.append({
                "Author": author,
                "Rating": rating
            })
        else:
            break

# %%
# convert the list of dictionaries into a DataFrame
df = pd.DataFrame(book_list)

print(df.head())

# save the DataFrame to a CSV file
df.to_csv("amazon_top_50_books_authors_ratings.csv", index=False)
# Out:
#                    Author              Rating
# 0                PR Yadav  4.4 out of 5 stars
# 1                     N/A  4.4 out of 5 stars
# 2  Oswaal Editorial Board  4.7 out of 5 stars
# 3          एम लक्ष्मीकांत  4.4 out of 5 stars
# 4      Wonder House Books  4.7 out of 5 stars

# %%
print(df.sample(10))
# Out:
#                            Author              Rating
# 43  Scholastic Teaching Resources  4.6 out of 5 stars
# 30                            N/A                 N/A
# 32                   Sweta Adatia  4.0 out of 5 stars
# 3                  एम लक्ष्मीकांत  4.4 out of 5 stars
# 29                     R.K. Gupta  4.5 out of 5 stars
# 2          Oswaal Editorial Board  4.7 out of 5 stars
# 34                         Mangal  4.5 out of 5 stars
# 25                Timothy Ferriss  4.5 out of 5 stars
# 28         ALLEN Expert Faculties  4.1 out of 5 stars
# 6         EduGorilla Prep Experts  4.2 out of 5 stars

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import numpy as np
from urllib.parse import urljoin
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import joblib
import os

def scrape_books_toscrape(base_url='http://books.toscrape.com/', num_pages=5):
    all_books = []
    for page in range(1, num_pages + 1):
        url = base_url if page == 1 else urljoin(base_url, f'catalogue/page-{page}.html')
        print(f"Scraping page {page}/{num_pages}: {url}")

        try:
            time.sleep(random.uniform(1, 3))
            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            book_containers = soup.select('article.product_pod')

            for book in book_containers:
                title = book.h3.a['title']
                price_text = book.select_one('div.product_price p.price_color').text
                price = re.sub(r'[^0-9.]', '', price_text)
                price = pd.to_numeric(price, errors='coerce')
                rating_class = book.select_one('p.star-rating')['class'][1]
                rating_map = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}
                rating = rating_map.get(rating_class, 0)

                availability_text = book.select_one('p.availability').text.strip()
                in_stock = 1 if 'In stock' in availability_text else 0
                detail_url = urljoin(base_url, book.h3.a['href'])
                category, description = "Unknown", "No description available"

                try:
                    time.sleep(random.uniform(0.5, 1.5))
                    detail_response = requests.get(detail_url, headers=headers)
                    detail_response.raise_for_status()
                    detail_soup = BeautifulSoup(detail_response.text, 'html.parser')
                    breadcrumb = detail_soup.select('ul.breadcrumb li')
                    if len(breadcrumb) >= 3:
                        category = breadcrumb[2].text.strip()
                    desc_element = detail_soup.select_one('div#product_description + p')
                    if desc_element:
                        description = desc_element.text.strip()
                except Exception as e:
                    print(f"Error fetching detail page for {title}: {e}")

                book_data = {'title': title, 'price': price, 'rating': rating, 'category': category,
                             'in_stock': in_stock, 'description': description, 'url': detail_url}
                all_books.append(book_data)
        except Exception as e:
            print(f"Error scraping page {page}: {e}")

    return pd.DataFrame(all_books)

def clean_book_data(df):
    df_clean = df.copy()
    df_clean['description'].fillna('No description available', inplace=True)
    df_clean['title_length'] = df_clean['title'].str.len()
    df_clean['desc_length'] = df_clean['description'].str.len()
    category_dummies = pd.get_dummies(df_clean['category'], prefix='category')
    return pd.concat([df_clean, category_dummies], axis=1)

def build_book_price_model(df):
    feature_cols = ['rating', 'in_stock', 'title_length', 'desc_length'] + [col for col in df.columns if col.startswith('category_')]
    y = df['price']
    X_numerical = df[feature_cols]
    X_num_train, X_num_test, y_train, y_test = train_test_split(X_numerical, y, test_size=0.2, random_state=42)

    title_vectorizer = TfidfVectorizer(max_features=100, stop_words='english')
    desc_vectorizer = TfidfVectorizer(max_features=200, stop_words='english')

    X_title_train = title_vectorizer.fit_transform(df.loc[X_num_train.index, 'title'])
    X_title_test = title_vectorizer.transform(df.loc[X_num_test.index, 'title'])
    X_desc_train = desc_vectorizer.fit_transform(df.loc[X_num_train.index, 'description'])
    X_desc_test = desc_vectorizer.transform(df.loc[X_num_test.index, 'description'])

    scaler = StandardScaler()
    X_num_train_scaled = scaler.fit_transform(X_num_train)
    X_num_test_scaled = scaler.transform(X_num_test)

    X_train_combined = np.hstack((X_num_train_scaled, X_title_train.toarray(), X_desc_train.toarray()))
    X_test_combined = np.hstack((X_num_test_scaled, X_title_test.toarray(), X_desc_test.toarray()))

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train_combined, y_train)
    y_pred = model.predict(X_test_combined)

    return {'model': model, 'feature_cols': feature_cols, 'title_vectorizer': title_vectorizer,
            'desc_vectorizer': desc_vectorizer, 'scaler': scaler,
            'metrics': {'mse': mean_squared_error(y_test, y_pred),
                        'rmse': np.sqrt(mean_squared_error(y_test, y_pred)),
                        'r2': r2_score(y_test, y_pred)}}

def save_model_components(model_data, output_dir='book_model'):
    os.makedirs(output_dir, exist_ok=True)
    joblib.dump(model_data['model'], f"{output_dir}/model.joblib")
    joblib.dump(model_data['title_vectorizer'], f"{output_dir}/title_vectorizer.joblib")
    joblib.dump(model_data['desc_vectorizer'], f"{output_dir}/desc_vectorizer.joblib")
    joblib.dump(model_data['scaler'], f"{output_dir}/scaler.joblib")
    pd.Series(model_data['feature_cols']).to_csv(f"{output_dir}/feature_cols.csv", index=False)

def main():
    books_df = scrape_books_toscrape(num_pages=10)
    books_df.to_csv("scraped_books_raw.csv", index=False)
    books_df_clean = clean_book_data(books_df)
    books_df_clean.to_csv("scraped_books_clean.csv", index=False)
    model_data = build_book_price_model(books_df_clean)
    save_model_components(model_data)
    print("Model training complete and components saved.")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1/10: http://books.toscrape.com/
# Scraping page 2/10: http://books.toscrape.com/catalogue/page-2.html
# Error fetching detail page for In Her Wake: 404 Client Error: Not Found for url: http://books.toscrape.com/in-her-wake_980/index.html
# Error fetching detail page for How Music Works: 404 Client Error: Not Found for url: http://books.toscrape.com/how-music-works_979/index.html
# Error fetching detail page for Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More: 404 Client Error: Not Found for url: http://books.toscrape.com/foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html
# Error fetching detail page for Chase Me (Paris Nights #2): 404 Client Error: Not Found for url: http://books.toscrape.com/chase-me-paris-nights-2_977/index.html
# Error fetching detail page for Black Dust: 404 Client Error: Not Found for url: http://books.toscrape.com/black-dust_976/index.html
# Error fetching detail page for Birdsong: A Story in Pictures: 404 Client Error: Not Found for url: http://books.toscrape.com/birdsong-a-story-in-pictures_975/index.html
# Error fetching detail page for America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana: 404 Client Error: Not Found for url: http://books.toscrape.com/americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974/index.html
# Error fetching detail page for Aladdin and His Wonderful Lamp: 404 Client Error: Not Found for url: http://books.toscrape.com/aladdin-and-his-wonderful-lamp_973/index.html
# Error fetching detail page for Worlds Elsewhere: Journeys Around Shakespeareâs Globe: 404 Client Error: Not Found for url: http://books.toscrape.com/worlds-elsewhere-journeys-around-shakespeares-globe_972/index.html
# Error fetching detail page for Wall and Piece: 404 Client Error: Not Found for url: http://books.toscrape.com/wall-and-piece_971/index.html
# Error fetching detail page for The Four Agreements: A Practical Guide to Personal Freedom: 404 Client Error: Not Found for url: http://books.toscrape.com/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html
# Error fetching detail page for The Five Love Languages: How to Express Heartfelt Commitment to Your Mate: 404 Client Error: Not Found for url: http://books.toscrape.com/the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969/index.html
# Error fetching detail page for The Elephant Tree: 404 Client Error: Not Found for url: http://books.toscrape.com/the-elephant-tree_968/index.html
# Error fetching detail page for The Bear and the Piano: 404 Client Error: Not Found for url: http://books.toscrape.com/the-bear-and-the-piano_967/index.html
# Error fetching detail page for Sophie's World: 404 Client Error: Not Found for url: http://books.toscrape.com/sophies-world_966/index.html
# Error fetching detail page for Penny Maybe: 404 Client Error: Not Found for url: http://books.toscrape.com/penny-maybe_965/index.html
# Error fetching detail page for Maude (1883-1993):She Grew Up with the country: 404 Client Error: Not Found for url: http://books.toscrape.com/maude-1883-1993she-grew-up-with-the-country_964/index.html
# Error fetching detail page for In a Dark, Dark Wood: 404 Client Error: Not Found for url: http://books.toscrape.com/in-a-dark-dark-wood_963/index.html
# Error fetching detail page for Behind Closed Doors: 404 Client Error: Not Found for url: http://books.toscrape.com/behind-closed-doors_962/index.html
# Error fetching detail page for You can't bury them all: Poems: 404 Client Error: Not Found for url: http://books.toscrape.com/you-cant-bury-them-all-poems_961/index.html
# Scraping page 3/10: http://books.toscrape.com/catalogue/page-3.html
# Error fetching detail page for Slow States of Collapse: Poems: 404 Client Error: Not Found for url: http://books.toscrape.com/slow-states-of-collapse-poems_960/index.html
# Error fetching detail page for Reasons to Stay Alive: 404 Client Error: Not Found for url: http://books.toscrape.com/reasons-to-stay-alive_959/index.html
# Error fetching detail page for Private Paris (Private #10): 404 Client Error: Not Found for url: http://books.toscrape.com/private-paris-private-10_958/index.html
# Error fetching detail page for #HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.: 404 Client Error: Not Found for url: http://books.toscrape.com/higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957/index.html
# Error fetching detail page for Without Borders (Wanderlove #1): 404 Client Error: Not Found for url: http://books.toscrape.com/without-borders-wanderlove-1_956/index.html
# Error fetching detail page for When We Collided: 404 Client Error: Not Found for url: http://books.toscrape.com/when-we-collided_955/index.html
# Error fetching detail page for We Love You, Charlie Freeman: 404 Client Error: Not Found for url: http://books.toscrape.com/we-love-you-charlie-freeman_954/index.html
# Error fetching detail page for Untitled Collection: Sabbath Poems 2014: 404 Client Error: Not Found for url: http://books.toscrape.com/untitled-collection-sabbath-poems-2014_953/index.html
# Error fetching detail page for Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness: 404 Client Error: Not Found for url: http://books.toscrape.com/unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952/index.html
# Error fetching detail page for Unicorn Tracks: 404 Client Error: Not Found for url: http://books.toscrape.com/unicorn-tracks_951/index.html
# Error fetching detail page for Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink: 404 Client Error: Not Found for url: http://books.toscrape.com/unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html
# Error fetching detail page for Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2): 404 Client Error: Not Found for url: http://books.toscrape.com/tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949/index.html
# Error fetching detail page for Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity: 404 Client Error: Not Found for url: http://books.toscrape.com/throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948/index.html
# Error fetching detail page for This One Summer: 404 Client Error: Not Found for url: http://books.toscrape.com/this-one-summer_947/index.html
# Error fetching detail page for Thirst: 404 Client Error: Not Found for url: http://books.toscrape.com/thirst_946/index.html
# Error fetching detail page for The Torch Is Passed: A Harding Family Story: 404 Client Error: Not Found for url: http://books.toscrape.com/the-torch-is-passed-a-harding-family-story_945/index.html
# Error fetching detail page for The Secret of Dreadwillow Carse: 404 Client Error: Not Found for url: http://books.toscrape.com/the-secret-of-dreadwillow-carse_944/index.html
# Error fetching detail page for The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!: 404 Client Error: Not Found for url: http://books.toscrape.com/the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943/index.html
# Error fetching detail page for The Past Never Ends: 404 Client Error: Not Found for url: http://books.toscrape.com/the-past-never-ends_942/index.html
# Error fetching detail page for The Natural History of Us (The Fine Art of Pretending #2): 404 Client Error: Not Found for url: http://books.toscrape.com/the-natural-history-of-us-the-fine-art-of-pretending-2_941/index.html
# Scraping page 4/10: http://books.toscrape.com/catalogue/page-4.html
# Error fetching detail page for The Nameless City (The Nameless City #1): 404 Client Error: Not Found for url: http://books.toscrape.com/the-nameless-city-the-nameless-city-1_940/index.html
# Error fetching detail page for The Murder That Never Was (Forensic Instincts #5): 404 Client Error: Not Found for url: http://books.toscrape.com/the-murder-that-never-was-forensic-instincts-5_939/index.html
# Error fetching detail page for The Most Perfect Thing: Inside (and Outside) a Bird's Egg: 404 Client Error: Not Found for url: http://books.toscrape.com/the-most-perfect-thing-inside-and-outside-a-birds-egg_938/index.html
# Error fetching detail page for The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy: 404 Client Error: Not Found for url: http://books.toscrape.com/the-mindfulness-and-acceptance-workbook-for-anxiety-a-guide-to-breaking-free-from-anxiety-phobias-and-worry-using-acceptance-and-commitment-therapy_937/index.html
# Error fetching detail page for The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing: 404 Client Error: Not Found for url: http://books.toscrape.com/the-life-changing-magic-of-tidying-up-the-japanese-art-of-decluttering-and-organizing_936/index.html
# Error fetching detail page for The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer: 404 Client Error: Not Found for url: http://books.toscrape.com/the-inefficiency-assassin-time-management-tactics-for-working-smarter-not-longer_935/index.html
# Error fetching detail page for The Gutsy Girl: Escapades for Your Life of Epic Adventure: 404 Client Error: Not Found for url: http://books.toscrape.com/the-gutsy-girl-escapades-for-your-life-of-epic-adventure_934/index.html
# Error fetching detail page for The Electric Pencil: Drawings from Inside State Hospital No. 3: 404 Client Error: Not Found for url: http://books.toscrape.com/the-electric-pencil-drawings-from-inside-state-hospital-no-3_933/index.html
# Error fetching detail page for The Death of Humanity: and the Case for Life: 404 Client Error: Not Found for url: http://books.toscrape.com/the-death-of-humanity-and-the-case-for-life_932/index.html
# Error fetching detail page for The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life: 404 Client Error: Not Found for url: http://books.toscrape.com/the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931/index.html
# Error fetching detail page for The Art Forger: 404 Client Error: Not Found for url: http://books.toscrape.com/the-art-forger_930/index.html
# Error fetching detail page for The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind: 404 Client Error: Not Found for url: http://books.toscrape.com/the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929/index.html
# Error fetching detail page for The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution: 404 Client Error: Not Found for url: http://books.toscrape.com/the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html
# Error fetching detail page for Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up: 404 Client Error: Not Found for url: http://books.toscrape.com/spark-joy-an-illustrated-master-class-on-the-art-of-organizing-and-tidying-up_927/index.html
# Error fetching detail page for Soul Reader: 404 Client Error: Not Found for url: http://books.toscrape.com/soul-reader_926/index.html
# Error fetching detail page for Security: 404 Client Error: Not Found for url: http://books.toscrape.com/security_925/index.html
# Error fetching detail page for Saga, Volume 6 (Saga (Collected Editions) #6): 404 Client Error: Not Found for url: http://books.toscrape.com/saga-volume-6-saga-collected-editions-6_924/index.html
# Error fetching detail page for Saga, Volume 5 (Saga (Collected Editions) #5): 404 Client Error: Not Found for url: http://books.toscrape.com/saga-volume-5-saga-collected-editions-5_923/index.html
# Error fetching detail page for Reskilling America: Learning to Labor in the Twenty-First Century: 404 Client Error: Not Found for url: http://books.toscrape.com/reskilling-america-learning-to-labor-in-the-twenty-first-century_922/index.html
# Error fetching detail page for Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15): 404 Client Error: Not Found for url: http://books.toscrape.com/rat-queens-vol-3-demons-rat-queens-collected-editions-11-15_921/index.html
# Scraping page 5/10: http://books.toscrape.com/catalogue/page-5.html
# Error fetching detail page for Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1): 404 Client Error: Not Found for url: http://books.toscrape.com/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html
# Error fetching detail page for Princess Between Worlds (Wide-Awake Princess #5): 404 Client Error: Not Found for url: http://books.toscrape.com/princess-between-worlds-wide-awake-princess-5_919/index.html
# Error fetching detail page for Pop Gun War, Volume 1: Gift: 404 Client Error: Not Found for url: http://books.toscrape.com/pop-gun-war-volume-1-gift_918/index.html
# Error fetching detail page for Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics: 404 Client Error: Not Found for url: http://books.toscrape.com/political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html
# Error fetching detail page for Patience: 404 Client Error: Not Found for url: http://books.toscrape.com/patience_916/index.html
# Error fetching detail page for Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1): 404 Client Error: Not Found for url: http://books.toscrape.com/outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html
# Error fetching detail page for orange: The Complete Collection 1 (orange: The Complete Collection #1): 404 Client Error: Not Found for url: http://books.toscrape.com/orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html
# Error fetching detail page for Online Marketing for Busy Authors: A Step-By-Step Guide: 404 Client Error: Not Found for url: http://books.toscrape.com/online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html
# Error fetching detail page for On a Midnight Clear: 404 Client Error: Not Found for url: http://books.toscrape.com/on-a-midnight-clear_912/index.html
# Error fetching detail page for Obsidian (Lux #1): 404 Client Error: Not Found for url: http://books.toscrape.com/obsidian-lux-1_911/index.html
# Error fetching detail page for My Paris Kitchen: Recipes and Stories: 404 Client Error: Not Found for url: http://books.toscrape.com/my-paris-kitchen-recipes-and-stories_910/index.html
# Error fetching detail page for Masks and Shadows: 404 Client Error: Not Found for url: http://books.toscrape.com/masks-and-shadows_909/index.html
# Error fetching detail page for Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed: 404 Client Error: Not Found for url: http://books.toscrape.com/mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html
# Error fetching detail page for Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8): 404 Client Error: Not Found for url: http://books.toscrape.com/lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html
# Error fetching detail page for Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4): 404 Client Error: Not Found for url: http://books.toscrape.com/lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906/index.html
# Error fetching detail page for Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12): 404 Client Error: Not Found for url: http://books.toscrape.com/lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html
# Error fetching detail page for Layered: Baking, Building, and Styling Spectacular Cakes: 404 Client Error: Not Found for url: http://books.toscrape.com/layered-baking-building-and-styling-spectacular-cakes_904/index.html
# Error fetching detail page for Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners): 404 Client Error: Not Found for url: http://books.toscrape.com/judo-seven-steps-to-black-belt-an-introductory-guide-for-beginners_903/index.html
# Error fetching detail page for Join: 404 Client Error: Not Found for url: http://books.toscrape.com/join_902/index.html
# Error fetching detail page for In the Country We Love: My Family Divided: 404 Client Error: Not Found for url: http://books.toscrape.com/in-the-country-we-love-my-family-divided_901/index.html
# Scraping page 6/10: http://books.toscrape.com/catalogue/page-6.html
# Error fetching detail page for Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine: 404 Client Error: Not Found for url: http://books.toscrape.com/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html
# Error fetching detail page for I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5): 404 Client Error: Not Found for url: http://books.toscrape.com/i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html
# Error fetching detail page for I am a Hero Omnibus Volume 1: 404 Client Error: Not Found for url: http://books.toscrape.com/i-am-a-hero-omnibus-volume-1_898/index.html
# Error fetching detail page for How to Be Miserable: 40 Strategies You Already Use: 404 Client Error: Not Found for url: http://books.toscrape.com/how-to-be-miserable-40-strategies-you-already-use_897/index.html
# Error fetching detail page for Her Backup Boyfriend (The Sorensen Family #1): 404 Client Error: Not Found for url: http://books.toscrape.com/her-backup-boyfriend-the-sorensen-family-1_896/index.html
# Error fetching detail page for Giant Days, Vol. 2 (Giant Days #5-8): 404 Client Error: Not Found for url: http://books.toscrape.com/giant-days-vol-2-giant-days-5-8_895/index.html
# Error fetching detail page for Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton: 404 Client Error: Not Found for url: http://books.toscrape.com/forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894/index.html
# Error fetching detail page for First and First (Five Boroughs #3): 404 Client Error: Not Found for url: http://books.toscrape.com/first-and-first-five-boroughs-3_893/index.html
# Error fetching detail page for Fifty Shades Darker (Fifty Shades #2): 404 Client Error: Not Found for url: http://books.toscrape.com/fifty-shades-darker-fifty-shades-2_892/index.html
# Error fetching detail page for Everydata: The Misinformation Hidden in the Little Data You Consume Every Day: 404 Client Error: Not Found for url: http://books.toscrape.com/everydata-the-misinformation-hidden-in-the-little-data-you-consume-every-day_891/index.html
# Error fetching detail page for Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master: 404 Client Error: Not Found for url: http://books.toscrape.com/dont-be-a-jerk-and-other-practical-advice-from-dogen-japans-greatest-zen-master_890/index.html
# Error fetching detail page for Danganronpa Volume 1: 404 Client Error: Not Found for url: http://books.toscrape.com/danganronpa-volume-1_889/index.html
# Error fetching detail page for Crown of Midnight (Throne of Glass #2): 404 Client Error: Not Found for url: http://books.toscrape.com/crown-of-midnight-throne-of-glass-2_888/index.html
# Error fetching detail page for Codename Baboushka, Volume 1: The Conclave of Death: 404 Client Error: Not Found for url: http://books.toscrape.com/codename-baboushka-volume-1-the-conclave-of-death_887/index.html
# Error fetching detail page for Camp Midnight: 404 Client Error: Not Found for url: http://books.toscrape.com/camp-midnight_886/index.html
# Error fetching detail page for Call the Nurse: True Stories of a Country Nurse on a Scottish Isle: 404 Client Error: Not Found for url: http://books.toscrape.com/call-the-nurse-true-stories-of-a-country-nurse-on-a-scottish-isle_885/index.html
# Error fetching detail page for Burning: 404 Client Error: Not Found for url: http://books.toscrape.com/burning_884/index.html
# Error fetching detail page for Bossypants: 404 Client Error: Not Found for url: http://books.toscrape.com/bossypants_883/index.html
# Error fetching detail page for Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions)): 404 Client Error: Not Found for url: http://books.toscrape.com/bitch-planet-vol-1-extraordinary-machine-bitch-planet-collected-editions_882/index.html
# Error fetching detail page for Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3): 404 Client Error: Not Found for url: http://books.toscrape.com/avatar-the-last-airbender-smoke-and-shadow-part-3-smoke-and-shadow-3_881/index.html
# Scraping page 7/10: http://books.toscrape.com/catalogue/page-7.html
# Error fetching detail page for Algorithms to Live By: The Computer Science of Human Decisions: 404 Client Error: Not Found for url: http://books.toscrape.com/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html
# Error fetching detail page for A World of Flavor: Your Gluten Free Passport: 404 Client Error: Not Found for url: http://books.toscrape.com/a-world-of-flavor-your-gluten-free-passport_879/index.html
# Error fetching detail page for A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations: 404 Client Error: Not Found for url: http://books.toscrape.com/a-piece-of-sky-a-grain-of-rice-a-memoir-in-four-meditations_878/index.html
# Error fetching detail page for A Murder in Time: 404 Client Error: Not Found for url: http://books.toscrape.com/a-murder-in-time_877/index.html
# Error fetching detail page for A Flight of Arrows (The Pathfinders #2): 404 Client Error: Not Found for url: http://books.toscrape.com/a-flight-of-arrows-the-pathfinders-2_876/index.html
# Error fetching detail page for A Fierce and Subtle Poison: 404 Client Error: Not Found for url: http://books.toscrape.com/a-fierce-and-subtle-poison_875/index.html
# Error fetching detail page for A Court of Thorns and Roses (A Court of Thorns and Roses #1): 404 Client Error: Not Found for url: http://books.toscrape.com/a-court-of-thorns-and-roses-a-court-of-thorns-and-roses-1_874/index.html
# Error fetching detail page for (Un)Qualified: How God Uses Broken People to Do Big Things: 404 Client Error: Not Found for url: http://books.toscrape.com/unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html
# Error fetching detail page for You Are What You Love: The Spiritual Power of Habit: 404 Client Error: Not Found for url: http://books.toscrape.com/you-are-what-you-love-the-spiritual-power-of-habit_872/index.html
# Error fetching detail page for William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4): 404 Client Error: Not Found for url: http://books.toscrape.com/william-shakespeares-star-wars-verily-a-new-hope-william-shakespeares-star-wars-4_871/index.html
# Error fetching detail page for Tuesday Nights in 1980: 404 Client Error: Not Found for url: http://books.toscrape.com/tuesday-nights-in-1980_870/index.html
# Error fetching detail page for Tracing Numbers on a Train: 404 Client Error: Not Found for url: http://books.toscrape.com/tracing-numbers-on-a-train_869/index.html
# Error fetching detail page for Throne of Glass (Throne of Glass #1): 404 Client Error: Not Found for url: http://books.toscrape.com/throne-of-glass-throne-of-glass-1_868/index.html
# Error fetching detail page for Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History: 404 Client Error: Not Found for url: http://books.toscrape.com/thomas-jefferson-and-the-tripoli-pirates-the-forgotten-war-that-changed-american-history_867/index.html
# Error fetching detail page for Thirteen Reasons Why: 404 Client Error: Not Found for url: http://books.toscrape.com/thirteen-reasons-why_866/index.html
# Error fetching detail page for The White Cat and the Monk: A Retelling of the Poem âPangur BÃ¡nâ: 404 Client Error: Not Found for url: http://books.toscrape.com/the-white-cat-and-the-monk-a-retelling-of-the-poem-pangur-ban_865/index.html
# Error fetching detail page for The Wedding Dress: 404 Client Error: Not Found for url: http://books.toscrape.com/the-wedding-dress_864/index.html
# Error fetching detail page for The Vacationers: 404 Client Error: Not Found for url: http://books.toscrape.com/the-vacationers_863/index.html
# Error fetching detail page for The Third Wave: An Entrepreneurâs Vision of the Future: 404 Client Error: Not Found for url: http://books.toscrape.com/the-third-wave-an-entrepreneurs-vision-of-the-future_862/index.html
# Error fetching detail page for The Stranger: 404 Client Error: Not Found for url: http://books.toscrape.com/the-stranger_861/index.html
# Scraping page 8/10: http://books.toscrape.com/catalogue/page-8.html
# Error fetching detail page for The Shadow Hero (The Shadow Hero): 404 Client Error: Not Found for url: http://books.toscrape.com/the-shadow-hero-the-shadow-hero_860/index.html
# Error fetching detail page for The Secret (The Secret #1): 404 Client Error: Not Found for url: http://books.toscrape.com/the-secret-the-secret-1_859/index.html
# Error fetching detail page for The Regional Office Is Under Attack!: 404 Client Error: Not Found for url: http://books.toscrape.com/the-regional-office-is-under-attack_858/index.html
# Error fetching detail page for The Psychopath Test: A Journey Through the Madness Industry: 404 Client Error: Not Found for url: http://books.toscrape.com/the-psychopath-test-a-journey-through-the-madness-industry_857/index.html
# Error fetching detail page for The Project: 404 Client Error: Not Found for url: http://books.toscrape.com/the-project_856/index.html
# Error fetching detail page for The Power of Now: A Guide to Spiritual Enlightenment: 404 Client Error: Not Found for url: http://books.toscrape.com/the-power-of-now-a-guide-to-spiritual-enlightenment_855/index.html
# Error fetching detail page for The Omnivore's Dilemma: A Natural History of Four Meals: 404 Client Error: Not Found for url: http://books.toscrape.com/the-omnivores-dilemma-a-natural-history-of-four-meals_854/index.html
# Error fetching detail page for The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us: 404 Client Error: Not Found for url: http://books.toscrape.com/the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853/index.html
# Error fetching detail page for The Murder of Roger Ackroyd (Hercule Poirot #4): 404 Client Error: Not Found for url: http://books.toscrape.com/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html
# Error fetching detail page for The Mistake (Off-Campus #2): 404 Client Error: Not Found for url: http://books.toscrape.com/the-mistake-off-campus-2_851/index.html
# Error fetching detail page for The Matchmaker's Playbook (Wingmen Inc. #1): 404 Client Error: Not Found for url: http://books.toscrape.com/the-matchmakers-playbook-wingmen-inc-1_850/index.html
# Error fetching detail page for The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking: 404 Client Error: Not Found for url: http://books.toscrape.com/the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849/index.html
# Error fetching detail page for The Long Shadow of Small Ghosts: Murder and Memory in an American City: 404 Client Error: Not Found for url: http://books.toscrape.com/the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html
# Error fetching detail page for The Kite Runner: 404 Client Error: Not Found for url: http://books.toscrape.com/the-kite-runner_847/index.html
# Error fetching detail page for The House by the Lake: 404 Client Error: Not Found for url: http://books.toscrape.com/the-house-by-the-lake_846/index.html
# Error fetching detail page for The Glittering Court (The Glittering Court #1): 404 Client Error: Not Found for url: http://books.toscrape.com/the-glittering-court-the-glittering-court-1_845/index.html
# Error fetching detail page for The Girl on the Train: 404 Client Error: Not Found for url: http://books.toscrape.com/the-girl-on-the-train_844/index.html
# Error fetching detail page for The Genius of Birds: 404 Client Error: Not Found for url: http://books.toscrape.com/the-genius-of-birds_843/index.html
# Error fetching detail page for The Emerald Mystery: 404 Client Error: Not Found for url: http://books.toscrape.com/the-emerald-mystery_842/index.html
# Error fetching detail page for The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First: 404 Client Error: Not Found for url: http://books.toscrape.com/the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841/index.html
# Scraping page 9/10: http://books.toscrape.com/catalogue/page-9.html
# Error fetching detail page for The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.: 404 Client Error: Not Found for url: http://books.toscrape.com/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html
# Error fetching detail page for The Artist's Way: A Spiritual Path to Higher Creativity: 404 Client Error: Not Found for url: http://books.toscrape.com/the-artists-way-a-spiritual-path-to-higher-creativity_839/index.html
# Error fetching detail page for The Art of War: 404 Client Error: Not Found for url: http://books.toscrape.com/the-art-of-war_838/index.html
# Error fetching detail page for The Argonauts: 404 Client Error: Not Found for url: http://books.toscrape.com/the-argonauts_837/index.html
# Error fetching detail page for The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job: 404 Client Error: Not Found for url: http://books.toscrape.com/the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836/index.html
# Error fetching detail page for Suddenly in Love (Lake Haven #1): 404 Client Error: Not Found for url: http://books.toscrape.com/suddenly-in-love-lake-haven-1_835/index.html
# Error fetching detail page for Something More Than This: 404 Client Error: Not Found for url: http://books.toscrape.com/something-more-than-this_834/index.html
# Error fetching detail page for Soft Apocalypse: 404 Client Error: Not Found for url: http://books.toscrape.com/soft-apocalypse_833/index.html
# Error fetching detail page for So You've Been Publicly Shamed: 404 Client Error: Not Found for url: http://books.toscrape.com/so-youve-been-publicly-shamed_832/index.html
# Error fetching detail page for Shoe Dog: A Memoir by the Creator of NIKE: 404 Client Error: Not Found for url: http://books.toscrape.com/shoe-dog-a-memoir-by-the-creator-of-nike_831/index.html
# Error fetching detail page for Shobu Samurai, Project Aryoku (#3): 404 Client Error: Not Found for url: http://books.toscrape.com/shobu-samurai-project-aryoku-3_830/index.html
# Error fetching detail page for Secrets and Lace (Fatal Hearts #1): 404 Client Error: Not Found for url: http://books.toscrape.com/secrets-and-lace-fatal-hearts-1_829/index.html
# Error fetching detail page for Scarlett Epstein Hates It Here: 404 Client Error: Not Found for url: http://books.toscrape.com/scarlett-epstein-hates-it-here_828/index.html
# Error fetching detail page for Romero and Juliet: A Tragic Tale of Love and Zombies: 404 Client Error: Not Found for url: http://books.toscrape.com/romero-and-juliet-a-tragic-tale-of-love-and-zombies_827/index.html
# Error fetching detail page for Redeeming Love: 404 Client Error: Not Found for url: http://books.toscrape.com/redeeming-love_826/index.html
# Error fetching detail page for Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form: 404 Client Error: Not Found for url: http://books.toscrape.com/poses-for-artists-volume-1-dynamic-and-sitting-poses-an-essential-reference-for-figure-drawing-and-the-human-form_825/index.html
# Error fetching detail page for Poems That Make Grown Women Cry: 404 Client Error: Not Found for url: http://books.toscrape.com/poems-that-make-grown-women-cry_824/index.html
# Error fetching detail page for Nightingale, Sing: 404 Client Error: Not Found for url: http://books.toscrape.com/nightingale-sing_823/index.html
# Error fetching detail page for Night Sky with Exit Wounds: 404 Client Error: Not Found for url: http://books.toscrape.com/night-sky-with-exit-wounds_822/index.html
# Error fetching detail page for Mrs. Houdini: 404 Client Error: Not Found for url: http://books.toscrape.com/mrs-houdini_821/index.html
# Scraping page 10/10: http://books.toscrape.com/catalogue/page-10.html
# Error fetching detail page for Modern Romance: 404 Client Error: Not Found for url: http://books.toscrape.com/modern-romance_820/index.html
# Error fetching detail page for Miss Peregrineâs Home for Peculiar Children (Miss Peregrineâs Peculiar Children #1): 404 Client Error: Not Found for url: http://books.toscrape.com/miss-peregrines-home-for-peculiar-children-miss-peregrines-peculiar-children-1_819/index.html
# Error fetching detail page for Louisa: The Extraordinary Life of Mrs. Adams: 404 Client Error: Not Found for url: http://books.toscrape.com/louisa-the-extraordinary-life-of-mrs-adams_818/index.html
# Error fetching detail page for Little Red: 404 Client Error: Not Found for url: http://books.toscrape.com/little-red_817/index.html
# Error fetching detail page for Library of Souls (Miss Peregrineâs Peculiar Children #3): 404 Client Error: Not Found for url: http://books.toscrape.com/library-of-souls-miss-peregrines-peculiar-children-3_816/index.html
# Error fetching detail page for Large Print Heart of the Pride: 404 Client Error: Not Found for url: http://books.toscrape.com/large-print-heart-of-the-pride_815/index.html
# Error fetching detail page for I Had a Nice Time And Other Lies...: How to find love & sh*t like that: 404 Client Error: Not Found for url: http://books.toscrape.com/i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814/index.html
# Error fetching detail page for Hollow City (Miss Peregrineâs Peculiar Children #2): 404 Client Error: Not Found for url: http://books.toscrape.com/hollow-city-miss-peregrines-peculiar-children-2_813/index.html
# Error fetching detail page for Grumbles: 404 Client Error: Not Found for url: http://books.toscrape.com/grumbles_812/index.html
# Error fetching detail page for Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond: 404 Client Error: Not Found for url: http://books.toscrape.com/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html
# Error fetching detail page for Frostbite (Vampire Academy #2): 404 Client Error: Not Found for url: http://books.toscrape.com/frostbite-vampire-academy-2_810/index.html
# Error fetching detail page for Follow You Home: 404 Client Error: Not Found for url: http://books.toscrape.com/follow-you-home_809/index.html
# Error fetching detail page for First Steps for New Christians (Print Edition): 404 Client Error: Not Found for url: http://books.toscrape.com/first-steps-for-new-christians-print-edition_808/index.html
# Error fetching detail page for Finders Keepers (Bill Hodges Trilogy #2): 404 Client Error: Not Found for url: http://books.toscrape.com/finders-keepers-bill-hodges-trilogy-2_807/index.html
# Error fetching detail page for Fables, Vol. 1: Legends in Exile (Fables #1): 404 Client Error: Not Found for url: http://books.toscrape.com/fables-vol-1-legends-in-exile-fables-1_806/index.html
# Error fetching detail page for Eureka Trivia 6.0: 404 Client Error: Not Found for url: http://books.toscrape.com/eureka-trivia-60_805/index.html
# Error fetching detail page for Drive: The Surprising Truth About What Motivates Us: 404 Client Error: Not Found for url: http://books.toscrape.com/drive-the-surprising-truth-about-what-motivates-us_804/index.html
# Error fetching detail page for Done Rubbed Out (Reightman & Bailey #1): 404 Client Error: Not Found for url: http://books.toscrape.com/done-rubbed-out-reightman-bailey-1_803/index.html
# Error fetching detail page for Doing It Over (Most Likely To #1): 404 Client Error: Not Found for url: http://books.toscrape.com/doing-it-over-most-likely-to-1_802/index.html
# Error fetching detail page for Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals: 404 Client Error: Not Found for url: http://books.toscrape.com/deliciously-ella-every-day-quick-and-easy-recipes-for-gluten-free-snacks-packed-lunches-and-simple-meals_801/index.html
# Model training complete and components saved.
